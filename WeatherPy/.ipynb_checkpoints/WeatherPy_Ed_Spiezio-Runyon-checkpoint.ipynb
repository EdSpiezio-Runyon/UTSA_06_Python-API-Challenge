# %% [markdown]
# # WeatherPy
#
# ---
# This script attempts to answer the general question "What is the weather like as we approach the equator?" by selecting random cities and and examining the relationship between latitude and temperature, humidity, cloudiness, and wind speed.
#
# This analysis functions with the use of Matplotlib, Pandas, Numpy, Requests, Time, Scipi, Weather API, and Citipy.

# %%
# Starter Code to Generate Random Geographic Coordinates and a List of Cities
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Generate the Cities List by Using the `citipy` Library
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 620

# %% [markdown]
# ### Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Define an empty list to fetch the weather data for each city
city_name = []
city_latitude = []
city_longitude = []
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url + city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_name.append(city_weather['name'])
        city_latitude.append(city_weather['coord']['lat'])
        city_longitude.append(city_weather['coord']['lon'])
        city_max_temp.append(city_weather['main']['temp_max'])
        city_humidity.append(city_weather['main']['humidity'])
        city_clouds.append(city_weather['clouds']['all'])
        city_wind.append(city_weather['wind']['speed'])
        city_country.append(city_weather['sys']['country'])
        city_date.append(city_weather['dt'])

        # Append the City information into city_data list
        city_data = {"City": city_name, 
                          "Lat": city_latitude, 
                          "Lng": city_longitude, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date}

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | jyvaskyla
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | beloha
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | ostrov
# Processing Record 13 of Set 1 | ponta delgada
# Processing Record 14 of Set 1 | syasstroy
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | henderson
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | plettenberg bay
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | laohekou
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | sola
# Processing Record 24 of Set 1 | sao filipe
# Processing Record 25 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | constitucion
# Processing Record 28 of Set 1 | paraiso
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | bustamante
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | oudtshoorn
# Processing Record 38 of Set 1 | port lincoln
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | khed brahma
# Processing Record 41 of Set 1 | vieux-habitants
# Processing Record 42 of Set 1 | souillac
# Processing Record 43 of Set 1 | ambanja
# Processing Record 44 of Set 1 | catuday
# Processing Record 45 of Set 1 | marawi
# Processing Record 46 of Set 1 | srednekolymsk
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | klaksvik
# Processing Record 49 of Set 1 | port hedland
# Processing Record 50 of Set 1 | college
# Processing Record 0 of Set 2 | hasaki
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | hobyo
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | tabou
# Processing Record 5 of Set 2 | leningradskiy
# Processing Record 6 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 2 | tromso
# Processing Record 8 of Set 2 | dzilam gonzalez
# Processing Record 9 of Set 2 | champerico
# Processing Record 10 of Set 2 | tessalit
# Processing Record 11 of Set 2 | geraldton
# Processing Record 12 of Set 2 | mangai
# Processing Record 13 of Set 2 | nalut
# Processing Record 14 of Set 2 | bilma
# Processing Record 15 of Set 2 | huangchuan
# Processing Record 16 of Set 2 | namatanai
# Processing Record 17 of Set 2 | caravelas
# Processing Record 18 of Set 2 | moussoro
# Processing Record 19 of Set 2 | balod
# Processing Record 20 of Set 2 | cayenne
# Processing Record 21 of Set 2 | perevolotskiy
# Processing Record 22 of Set 2 | ambunti
# Processing Record 23 of Set 2 | asau
# Processing Record 24 of Set 2 | opuwo
# Processing Record 25 of Set 2 | guerrero negro
# Processing Record 26 of Set 2 | colares
# Processing Record 27 of Set 2 | boca do acre
# Processing Record 28 of Set 2 | rudolstadt
# Processing Record 29 of Set 2 | lebu
# Processing Record 30 of Set 2 | ponta do sol
# Processing Record 31 of Set 2 | kudahuvadhoo
# Processing Record 32 of Set 2 | arroyo
# Processing Record 33 of Set 2 | fort nelson
# Processing Record 34 of Set 2 | sistranda
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | lompoc
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | khandyga
# Processing Record 39 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 2 | ketchikan
# Processing Record 41 of Set 2 | victoria
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | tshikapa
# Processing Record 45 of Set 2 | poso
# Processing Record 46 of Set 2 | shubarkuduk
# Processing Record 47 of Set 2 | balykshi
# Processing Record 48 of Set 2 | san patricio
# Processing Record 49 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 0 of Set 3 | pisco
# Processing Record 1 of Set 3 | bengkulu
# Processing Record 2 of Set 3 | batemans bay
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | malakal
# Processing Record 5 of Set 3 | dingle
# Processing Record 6 of Set 3 | terney
# Processing Record 7 of Set 3 | jaicos
# Processing Record 8 of Set 3 | lasa
# Processing Record 9 of Set 3 | matara
# Processing Record 10 of Set 3 | ribeira grande
# Processing Record 11 of Set 3 | chara
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | inuvik
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | airai
# Processing Record 16 of Set 3 | acapulco
# Processing Record 17 of Set 3 | samarai
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | antalaha
# Processing Record 20 of Set 3 | tasiilaq
# Processing Record 21 of Set 3 | taltal
# Processing Record 22 of Set 3 | ngunguru
# Processing Record 23 of Set 3 | buenos aires
# Processing Record 24 of Set 3 | kruisfontein
# Processing Record 25 of Set 3 | bulalacao
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | sibu
# Processing Record 28 of Set 3 | mount isa
# Processing Record 29 of Set 3 | myre
# Processing Record 30 of Set 3 | esmeraldas
# Processing Record 31 of Set 3 | sharjah
# Processing Record 32 of Set 3 | tucurui
# Processing Record 33 of Set 3 | babu
# Processing Record 34 of Set 3 | tilichiki
# Processing Record 35 of Set 3 | aloleng
# Processing Record 36 of Set 3 | corn island
# Processing Record 37 of Set 3 | katsuura
# Processing Record 38 of Set 3 | banepa
# Processing Record 39 of Set 3 | nikolskoye
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | indri
# Processing Record 42 of Set 3 | wageningen
# Processing Record 43 of Set 3 | karratha
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | vaini
# Processing Record 46 of Set 3 | pontianak
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | kulhudhuffushi
# Processing Record 0 of Set 4 | avarua
# Processing Record 1 of Set 4 | pombal
# Processing Record 2 of Set 4 | mar del plata
# Processing Record 3 of Set 4 | kalmar
# Processing Record 4 of Set 4 | atar
# Processing Record 5 of Set 4 | grindavik
# Processing Record 6 of Set 4 | butaritari
# Processing Record 7 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | maceio
# Processing Record 10 of Set 4 | faanui
# Processing Record 11 of Set 4 | mackay
# Processing Record 12 of Set 4 | arraial do cabo
# Processing Record 13 of Set 4 | westport
# Processing Record 14 of Set 4 | khatanga
# Processing Record 15 of Set 4 | vanavara
# Processing Record 16 of Set 4 | terrace bay
# Processing Record 17 of Set 4 | zhigansk
# Processing Record 18 of Set 4 | siocon
# Processing Record 19 of Set 4 | shubarshi
# Processing Record 20 of Set 4 | bereda
# Processing Record 21 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 22 of Set 4 | tura
# Processing Record 23 of Set 4 | vila
# Processing Record 24 of Set 4 | lavrentiya
# Processing Record 25 of Set 4 | tezu
# Processing Record 26 of Set 4 | bandar
# Processing Record 27 of Set 4 | abu samrah
# Processing Record 28 of Set 4 | bundaberg
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | dordrecht
# Processing Record 31 of Set 4 | naryan-mar
# Processing Record 32 of Set 4 | sauda
# Processing Record 33 of Set 4 | vila velha
# Processing Record 34 of Set 4 | nanortalik
# Processing Record 35 of Set 4 | mangrol
# Processing Record 36 of Set 4 | tuatapere
# Processing Record 37 of Set 4 | bois-guillaume
# Processing Record 38 of Set 4 | kurush
# Processing Record 39 of Set 4 | maragogi
# Processing Record 40 of Set 4 | auki
# Processing Record 41 of Set 4 | fort-shevchenko
# Processing Record 42 of Set 4 | tuy hoa
# Processing Record 43 of Set 4 | hermanus
# Processing Record 44 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 4 | milas
# Processing Record 46 of Set 4 | pimentel
# Processing Record 47 of Set 4 | buraydah
# Processing Record 48 of Set 4 | atasu
# Processing Record 49 of Set 4 | barrow
# Processing Record 0 of Set 5 | margate
# Processing Record 1 of Set 5 | foumbot
# Processing Record 2 of Set 5 | kodiak
# Processing Record 3 of Set 5 | bonthe
# Processing Record 4 of Set 5 | husavik
# Processing Record 5 of Set 5 | ostrovnoy
# Processing Record 6 of Set 5 | bairiki
# Processing Record 7 of Set 5 | galle
# Processing Record 8 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 5 | vanimo
# Processing Record 10 of Set 5 | nhulunbuy
# Processing Record 11 of Set 5 | torbay
# Processing Record 12 of Set 5 | kedrovyy
# Processing Record 13 of Set 5 | bubaque
# Processing Record 14 of Set 5 | belle fourche
# Processing Record 15 of Set 5 | ilulissat
# Processing Record 16 of Set 5 | maraa
# Processing Record 17 of Set 5 | zeya
# Processing Record 18 of Set 5 | yatou
# Processing Record 19 of Set 5 | najran
# Processing Record 20 of Set 5 | argelia
# Processing Record 21 of Set 5 | korla
# Processing Record 22 of Set 5 | vao
# Processing Record 23 of Set 5 | gorontalo
# Processing Record 24 of Set 5 | andenes
# Processing Record 25 of Set 5 | harper
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | sirajganj
# Processing Record 28 of Set 5 | saskylakh
# Processing Record 29 of Set 5 | kavaratti
# Processing Record 30 of Set 5 | gondar
# Processing Record 31 of Set 5 | asandh
# Processing Record 32 of Set 5 | jonesboro
# Processing Record 33 of Set 5 | carnarvon
# Processing Record 34 of Set 5 | vulcan
# Processing Record 35 of Set 5 | correntina
# Processing Record 36 of Set 5 | malia
# Processing Record 37 of Set 5 | abu dhabi
# Processing Record 38 of Set 5 | palembang
# Processing Record 39 of Set 5 | san cristobal
# Processing Record 40 of Set 5 | la romana
# Processing Record 41 of Set 5 | flin flon
# Processing Record 42 of Set 5 | altay
# Processing Record 43 of Set 5 | akyab
# Processing Record 44 of Set 5 | montepuez
# Processing Record 45 of Set 5 | okha
# Processing Record 46 of Set 5 | yerbogachen
# Processing Record 47 of Set 5 | cidreira
# Processing Record 48 of Set 5 | ozernovskiy
# Processing Record 49 of Set 5 | cutro
# Processing Record 0 of Set 6 | itarema
# Processing Record 1 of Set 6 | pasighat
# Processing Record 2 of Set 6 | longyearbyen
# Processing Record 3 of Set 6 | banon
# Processing Record 4 of Set 6 | artigas
# Processing Record 5 of Set 6 | ahipara
# Processing Record 6 of Set 6 | aswan
# Processing Record 7 of Set 6 | narsaq
# Processing Record 8 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 6 | san quintin
# Processing Record 10 of Set 6 | salina
# Processing Record 11 of Set 6 | saint george
# Processing Record 12 of Set 6 | lanzhou
# Processing Record 13 of Set 6 | puntarenas
# Processing Record 14 of Set 6 | santiago del estero
# Processing Record 15 of Set 6 | alpena
# Processing Record 16 of Set 6 | pointe michel
# Processing Record 17 of Set 6 | tokur
# Processing Record 18 of Set 6 | shimoda
# Processing Record 19 of Set 6 | xining
# Processing Record 20 of Set 6 | carutapera
# Processing Record 21 of Set 6 | mehamn
# Processing Record 22 of Set 6 | antofagasta
# Processing Record 23 of Set 6 | cap malheureux
# Processing Record 24 of Set 6 | churapcha
# Processing Record 25 of Set 6 | saint-augustin
# Processing Record 26 of Set 6 | noyon
# Processing Record 27 of Set 6 | sibolga
# Processing Record 28 of Set 6 | luwuk
# Processing Record 29 of Set 6 | eydhafushi
# Processing Record 30 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 6 | atlantis
# Processing Record 32 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 33 of Set 6 | saldanha
# Processing Record 34 of Set 6 | cabo san lucas
# Processing Record 35 of Set 6 | senador jose porfirio
# Processing Record 36 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 6 | mattru
# Processing Record 38 of Set 6 | salou
# Processing Record 39 of Set 6 | arica
# Processing Record 40 of Set 6 | gunib
# Processing Record 41 of Set 6 | bambous virieux
# Processing Record 42 of Set 6 | iqaluit
# Processing Record 43 of Set 6 | eureka
# Processing Record 44 of Set 6 | taoudenni
# Processing Record 45 of Set 6 | aksarka
# Processing Record 46 of Set 6 | iquique
# Processing Record 47 of Set 6 | mahabad
# Processing Record 48 of Set 6 | asyut
# Processing Record 49 of Set 6 | yandoon
# City not found. Skipping...
# Processing Record 0 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 7 | ust-karsk
# Processing Record 2 of Set 7 | tselinnoye
# Processing Record 3 of Set 7 | nantucket
# Processing Record 4 of Set 7 | hithadhoo
# Processing Record 5 of Set 7 | yaring
# Processing Record 6 of Set 7 | olginskaya
# Processing Record 7 of Set 7 | juifang
# City not found. Skipping...
# Processing Record
of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 9 of Set 9 | qui nhon
# Processing Record 10 of Set 9 | chandbali
# Processing Record 11 of Set 9 | necochea
# Processing Record 12 of Set 9 | george town
# Processing Record 13 of Set 9 | pangkalanbuun
# Processing Record 14 of Set 9 | tartki
# City not found. Skipping...
# Processing Record 15 of Set 9 | slave lake
# Processing Record 16 of Set 9 | santa maria do suacui
# Processing Record 17 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 18 of Set 9 | paamiut
# Processing Record 19 of Set 9 | volksrust
# Processing Record 20 of Set 9 | hofn
# Processing Record 21 of Set 9 | ahuimanu
# Processing Record 22 of Set 9 | marsh harbour
# Processing Record 23 of Set 9 | linkou
# Processing Record 24 of Set 9 | tadine
# Processing Record 25 of Set 9 | mungwi
# Processing Record 26 of Set 9 | luau
# Processing Record 27 of Set 9 | fundao
# Processing Record 28 of Set 9 | alta floresta
# Processing Record 29 of Set 9 | cherskiy
# Processing Record 30 of Set 9 | jalu
# Processing Record 31 of Set 9 | nizhniy lomov
# Processing Record 32 of Set 9 | muros
# Processing Record 33 of Set 9 | honiara
# Processing Record 34 of Set 9 | carbonia
# Processing Record 35 of Set 9 | mandalgovi
# Processing Record 36 of Set 9 | port hardy
# Processing Record 37 of Set 9 | codajas
# Processing Record 38 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 9 | talnakh
# Processing Record 40 of Set 9 | ryotsu
# Processing Record 41 of Set 9 | agdas
# Processing Record 42 of Set 9 | vostok
# Processing Record 43 of Set 9 | teguldet
# Processing Record 44 of Set 9 | la ronge
# Processing Record 45 of Set 9 | rockland
# Processing Record 46 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 47 of Set 9 | salalah
# Processing Record 48 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 9 | maldonado
# Processing Record 0 of Set 10 | safaga
# Processing Record 1 of Set 10 | udachnyy
# Processing Record 2 of Set 10 | hovd
# Processing Record 3 of Set 10 | tyup
# Processing Record 4 of Set 10 | vila franca do campo
# Processing Record 5 of Set 10 | camana
# Processing Record 6 of Set 10 | batticaloa
# Processing Record 7 of Set 10 | oakdale
# Processing Record 8 of Set 10 | campagna
# Processing Record 9 of Set 10 | carballo
# Processing Record 10 of Set 10 | parrita
# Processing Record 11 of Set 10 | noumea
# Processing Record 12 of Set 10 | west wendover
# Processing Record 13 of Set 10 | gisenyi
# Processing Record 14 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 10 | sokolo
# Processing Record 17 of Set 10 | yuli
# Processing Record 18 of Set 10 | kathmandu
# Processing Record 19 of Set 10 | nicoya
# Processing Record 20 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 10 | shingu
# Processing Record 22 of Set 10 | sinnamary
# Processing Record 23 of Set 10 | upernavik
# Processing Record 24 of Set 10 | mae hong son
# Processing Record 25 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 10 | manbij
# Processing Record 27 of Set 10 | nyurba
# Processing Record 28 of Set 10 | yuzhno-kurilsk
# Processing Record 29 of Set 10 | matay
# Processing Record 30 of Set 10 | khilok
# Processing Record 31 of Set 10 | leshukonskoye
# Processing Record 32 of Set 10 | chauk
# Processing Record 33 of Set 10 | muravlenko
# Processing Record 34 of Set 10 | palaikastron
# Processing Record 35 of Set 10 | mountain home
# Processing Record 36 of Set 10 | villa rica
# Processing Record 37 of Set 10 | antequera
# Processing Record 38 of Set 10 | ghanzi
# Processing Record 39 of Set 10 | finnsnes
# Processing Record 40 of Set 10 | knyaginino
# Processing Record 41 of Set 10 | ancud
# Processing Record 42 of Set 10 | vestmannaeyjar
# Processing Record 43 of Set 10 | puerto madero
# Processing Record 44 of Set 10 | terrak
# Processing Record 45 of Set 10 | ladario
# Processing Record 46 of Set 10 | sedalia
# Processing Record 47 of Set 10 | kalispell
# Processing Record 48 of Set 10 | herouville-saint-clair
# Processing Record 49 of Set 10 | kutum
# Processing Record 0 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 1 of Set 11 | chicama
# Processing Record 2 of Set 11 | opatovice nad labem
# Processing Record 3 of Set 11 | narrabri
# Processing Record 4 of Set 11 | vohibinany
# Processing Record 5 of Set 11 | dubrovnik
# Processing Record 6 of Set 11 | castelldefels
# Processing Record 7 of Set 11 | novyy urengoy
# Processing Record 8 of Set 11 | terrace
# Processing Record 9 of Set 11 | privolzhskiy
# Processing Record 10 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 11 of Set 11 | mahajanga
# Processing Record 12 of Set 11 | chingirlau
# Processing Record 13 of Set 11 | yefira
# City not found. Skipping...
# Processing Record 14 of Set 11 | damaturu
# Processing Record 15 of Set 11 | granville
# Processing Record 16 of Set 11 | bollnas
# Processing Record 17 of Set 11 | damghan
# Processing Record 18 of Set 11 | cassilandia
# Processing Record 19 of Set 11 | palasa
# Processing Record 20 of Set 11 | orocue
# Processing Record 21 of Set 11 | anadyr
# Processing Record 22 of Set 11 | mandiana
# Processing Record 23 of Set 11 | were ilu
# Processing Record 24 of Set 11 | dwarka
# Processing Record 25 of Set 11 | kerikeri
# Processing Record 26 of Set 11 | tirumullaivasal
# Processing Record 27 of Set 11 | cockburn town
# Processing Record 28 of Set 11 | yarada
# Processing Record 29 of Set 11 | klos
# Processing Record 30 of Set 11 | otane
# Processing Record 31 of Set 11 | luena
# Processing Record 32 of Set 11 | aklavik
# Processing Record 33 of Set 11 | almansa
# Processing Record 34 of Set 11 | bonavista
# Processing Record 35 of Set 11 | gubkinskiy
# Processing Record 36 of Set 11 | verkhnyaya balkariya
# Processing Record 37 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 11 | sur
# Processing Record 39 of Set 11 | benalla
# Processing Record 40 of Set 11 | raichur
# Processing Record 41 of Set 11 | saint-francois
# Processing Record 42 of Set 11 | guardiagrele
# Processing Record 43 of Set 11 | karaman
# Processing Record 44 of Set 11 | morant bay
# Processing Record 45 of Set 11 | cobija
# Processing Record 46 of Set 11 | sept-iles
# Processing Record 47 of Set 11 | saryozek
# Processing Record 48 of Set 11 | palana
# Processing Record 49 of Set 11 | coihaique
# Processing Record 0 of Set 12 | laje
# Processing Record 1 of Set 12 | houma
# Processing Record 2 of Set 12 | gouyave
# Processing Record 3 of Set 12 | massakory
# Processing Record 4 of Set 12 | sangar
# Processing Record 5 of Set 12 | dajal
# Processing Record 6 of Set 12 | mbanza-ngungu
# Processing Record 7 of Set 12 | vardo
# Processing Record 8 of Set 12 | esperance
# Processing Record 9 of Set 12 | voi
# Processing Record 10 of Set 12 | the valley
# Processing Record 11 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 12 of Set 12 | berlevag
# Processing Record 13 of Set 12 | los llanos de aridane
# Processing Record 14 of Set 12 | suluq
# Processing Record 15 of Set 12 | bartica
# Processing Record 16 of Set 12 | ardakan
# Processing Record 17 of Set 12 | gazanjyk
# Processing Record 18 of Set 12 | vernon
# Processing Record 19 of Set 12 | lebedinyy
# Processing Record 20 of Set 12 | fochabers
# Processing Record 21 of Set 12 | kalawit
# Processing Record 22 of Set 12 | mayo
# Processing Record 23 of Set 12 | sandwick
# Processing Record 24 of Set 12 | huai yot
# Processing Record 25 of Set 12 | vestmanna
# Processing Record 26 of Set 12 | waingapu
# Processing Record 27 of Set 12 | omidiyeh
# Processing Record 28 of Set 12 | amapa
# Processing Record 29 of Set 12 | abonnema
# Processing Record 30 of Set 12 | avera
# Processing Record 31 of Set 12 | kumluca
# Processing Record 32 of Set 12 | makakilo city
# Processing Record 33 of Set 12 | coahuayana
# Processing Record 34 of Set 12 | cozumel
# Processing Record 35 of Set 12 | kamisu
# Processing Record 36 of Set 12 | lichinga
# Processing Record 37 of Set 12 | farafangana
# Processing Record 38 of Set 12 | manono
# Processing Record 39 of Set 12 | katherine
# Processing Record 40 of Set 12 | banda aceh
# Processing Record 41 of Set 12 | ixtapa
# Processing Record 42 of Set 12 | suntar
# Processing Record 43 of Set 12 | riacho de santana
# Processing Record 44 of Set 12 | ariquemes
# Processing Record 45 of Set 12 | xam nua
# Processing Record 46 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 47 of Set 12 | burgos
# Processing Record 48 of Set 12 | almeria
# Processing Record 49 of Set 12 | bambanglipuro
# Processing Record 0 of Set 13 | hay river
# Processing Record 1 of Set 13 | nabul
# City not found. Skipping...
# Processing Record 2 of Set 13 | burica
# City not found. Skipping...
# Processing Record 3 of Set 13 | soyo
# Processing Record 4 of Set 13 | elizabeth city
# Processing Record 5 of Set 13 | nome
# Processing Record 6 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 13 | oistins
# Processing Record 8 of Set 13 | flinders
# Processing Record 9 of Set 13 | nynashamn
# Processing Record 10 of Set 13 | touros
# Processing Record 11 of Set 13 | la rioja
# Processing Record 12 of Set 13 | tecoanapa
# Processing Record 13 of Set 13 | rajgir
# Processing Record 14 of Set 13 | alice springs
# Processing Record 15 of Set 13 | aketi
# Processing Record 16 of Set 13 | puerto ayacucho
# Processing Record 17 of Set 13 | bandarbeyla
# Processing Record 18 of Set 13 | bloomington
# Processing Record 19 of Set 13 | kamenskoye
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
weather_data_df = pd.DataFrame(city_data)

# Show Record Count
weather_data_df.count()
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
# Display sample data
weather_data_df.head(50)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             
# 16       26.46      CL  1667532897
# 17        3.76      ZA  1667532898
# 18        2.30      ZA  1667532898
# 19        5.39      CN  1667532898
# 20        0.00      VU  1667532899
# 21        7.78      CV  1667532900
# 22        6.22      RU  1667532900
# 23        1.48      CL  1667532656
# 24        1.21      CR  1667532901
# 25       12.01      ZA  1667532902
# 26       11.50      CA  1667532902
# 27        2.64      PG  1667532903
# 28        4.36      BR  1667532605
# 29        9.22      MU  1667532904
# 30       13.82      MX  1667532904
# 31        8.99      ZA  1667532714
# 32       13.87      RU  1667532905
# 33        0.76      ZA  1667532905
# 34        9.75      AU  1667532906
# 35        5.75      MY  1667532832
# 36        2.44      IN  1667532907
# 37       11.36      GP  1667532907
# 38        9.22      MU  1667532908
# 39        1.61      MG  1667532908
# 40       11.36      PH  1667532909
# 41        4.90      PH  1667532910
# 42        2.71      RU  1667532910
# 43       14.97      CA  1667532911
# 44       29.95      FO  1667532911
# 45       12.66      AU  1667532727
# 46        6.91      US  1667532912
# 47       23.62      JP  1667532912
# 48       14.12      PF  1667532913
# 49        4.03      SO  1667532914

# %%
# Export the City_Data into a csv
weather_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
weather_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
weather_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               Tiksi  71.6872  128.8694     -3.73        98          60
# 1                Chui -33.6971  -53.4616     52.66        80           1
# 2           Jyvaskyla  62.2415   25.7209     41.34        98         100
# 3             Rikitea -23.1203 -134.9692     70.36        70         100
# 4        Puerto Ayora  -0.7393  -90.3518     67.28        84          68
#
#          Wind Speed Country        Date
# City_ID
# 0              7.40      RU  1667532890
# 1              5.44      UY  1667532891
# 2              4.61      FI  1667532891
# 3             16.84      PF  1667532779
# 4              9.51      EC  1667532892

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
date = time.strftime("%m/%d/%y")
x_values = weather_data_df["Lat"]
y_values = weather_data_df["Max Temp"]
plt.scatter(x_values, y_values, alpha = 0.7, edgecolor = "k")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1_LatVsTemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
date = time.strftime("%m/%d/%y")
x_values = weather_data_df["Lat"]
y_values = weather_data_df["Humidity"]
plt.scatter(x_values, y_values, alpha = 0.7, edgecolor = "k")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Humidity ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2_LatVsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
date = time.strftime("%m/%d/%y")
x_values = weather_data_df["Lat"]
y_values = weather_data_df["Cloudiness"]
plt.scatter(x_values, y_values, alpha = 0.7, edgecolor = "k")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3_LatVsCloud.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
date = time.strftime("%m/%d/%y")
x_values = weather_data_df["Lat"]
y_values = weather_data_df["Wind Speed"]
plt.scatter(x_values, y_values, alpha = 0.7, edgecolor = "k")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4_LatVsWind.png")

# Show plot
plt.show()

# %%
### Requirement 2: Compute Linear Regression for Each Relationship

# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)
# Out:
# City_ID
# 0      7.941935
# 1      7.458107
# 2      7.898569
# 3      7.506666
# 4      7.609419
#          ...
# 565    7.504005
# 566    7.625387
# 567    7.638817
# 568    7.656402
# 569    7.818681
# Name: Lat, Length: 570, dtype: float64

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
north_hemi = weather_data_df.loc[weather_data_df["Lat"] >= 0]

northern_hemi_df = pd.DataFrame(north_hemi)

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            Tiksi  71.6872  128.8694     -3.73        98          60
# 2        Jyvaskyla  62.2415   25.7209     41.34        98         100
# 8             Hilo  19.7297 -155.0900     76.62        86          75
# 9           Albany  42.6001  -73.9662     55.81        69           0
# 10          Ostrov  57.3439   28.3537     38.93        89          93
#
#          Wind Speed Country        Date
# City_ID
# 0              7.40      RU  1667532890
# 2              4.61      FI  1667532891
# 8              5.01      US  1667532894
# 9              1.01      US  1667532682
# 10             3.31      RU  1667532895

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
south_hemi = weather_data_df.loc[weather_data_df["Lat"] < 0]

southern_hemi_df = pd.DataFrame(south_hemi)

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                Chui -33.6971  -53.4616     52.66        80           1
# 3             Rikitea -23.1203 -134.9692     70.36        70         100
# 4        Puerto Ayora  -0.7393  -90.3518     67.28        84          68
# 5               Bluff -46.6000  168.3333     50.52        80          93
# 6             Mataura -46.1927  168.8643     52.66        72          78
#
#          Wind Speed Country        Date
# City_ID
# 1              5.44      UY  1667532891
# 3             16.84      PF  1667532779
# 4              9.51      EC  1667532892
# 5             34.36      NZ  1667532892
# 6             12.75      NZ  1667532893

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
date = time.strftime("%m/%d/%y")
x_values = north_hemi["Lat"]
y_values = north_hemi["Max Temp"]

# Get linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Build linear regression plot
plt.scatter(x_values, y_values, alpha = 0.7, edgecolors = "k")
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (5, -10), fontsize = 10, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title(f"Northern Hemisphere - City Latitude vs. Temperature ({date})", fontsize = 10)
plt.grid(True)
print(f"The r-value is: {rvalue**2}") 

# Save linear regression plot as a png
plt.savefig("output_data/RegressionPlot_NorthernHemisphere_LatitudeVsTemperature.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7562569289829809

# %%
# Linear regression on Southern Hemisphere
date = time.strftime("%m/%d/%y")
x_values = south_hemi["Lat"]
y_values = south_hemi["Max Temp"]

# Get linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Build linear regression plot
plt.scatter(x_values, y_values, alpha = 0.7, edgecolors = "k")
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (-52, 87), fontsize = 10, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title(f"Southern Hemisphere - City Latitude vs. Temperature ({date})", fontsize = 10)
plt.grid(True)
print(f"The r-value is: {rvalue**2}") 

# Save linear regression plot as a png
plt.savefig("output_data/RegressionPlot_SouthernHemisphere_LatitudeVsTemperature.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.31983157506355214

# %% [markdown]
# **Discussion about the linear relationship:**
#
# From the data and regression analyses, a very strong correlation exists between city latitude and temperature. This is particularly true in the northern hemisphere, where the r-value nears 0.75 and the slope slightly exceeds -1.  The southern hemisphere also follows this trend, but latitude and temperature are less strongly correlated.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
date = time.strftime("%m/%d/%y")
x_values = north_hemi["Lat"]
y_values = north_hemi["Humidity"]

# Get linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Build linear regression plot
plt.scatter(x_values, y_values, alpha = 0.7, edgecolors = "k")
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (45, 15), fontsize = 10, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Northern Hemisphere - City Latitude vs. Humidity ({date})", fontsize = 10)
plt.grid(True)
print(f"The r-value is: {rvalue**2}") 

# Save linear regression plot as a png
plt.savefig("output_data/RegressionPlot_NorthernHemisphere_LatitudeVsHumidity.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.06033636375061029

# %%
# Southern Hemisphere
date = time.strftime("%m/%d/%y")
x_values = south_hemi["Lat"]
y_values = south_hemi["Humidity"]

# Get linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Build linear regression plot
plt.scatter(x_values, y_values, alpha = 0.7, edgecolors = "k")
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (-55, 15), fontsize = 10, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Southern Hemisphere - City Latitude vs. Humidity ({date})", fontsize = 10)
plt.grid(True)
print(f"The r-value is: {rvalue**2}") 

# Save linear regression plot as a png
plt.savefig("output_data/RegressionPlot_SouthernHemisphere_LatitudeVsHumidity.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.035257342871571756

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There appears to be no significance in correlation between latitude and humidity.  In these analyses, the r-value is essentially zero.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
date = time.strftime("%m/%d/%y")
x_values = north_hemi["Lat"]
y_values = north_hemi["Cloudiness"]

# Get linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Build linear regression plot
plt.scatter(x_values, y_values, alpha = 0.7, edgecolors = "k")
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (57, 43), fontsize = 10, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"Northern Hemisphere - City Latitude vs. Cloudiness ({date})", fontsize = 10)
plt.grid(True)
print(f"The r-value is: {rvalue**2}") 

# Save linear regression plot as a png
plt.savefig("output_data/RegressionPlot_NorthernHemisphere_LatitudeVsCloudiness.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.04328635235814332

# %%
# Southern Hemisphere
date = time.strftime("%m/%d/%y")
x_values = south_hemi["Lat"]
y_values = south_hemi["Cloudiness"]

# Get linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Build linear regression plot
plt.scatter(x_values, y_values, alpha = 0.7, edgecolors = "k")
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (-55, 7), fontsize = 10, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"Southern Hemisphere - City Latitude vs. Cloudiness ({date})", fontsize = 10)
plt.grid(True)
print(f"The r-value is: {rvalue**2}") 

# Save linear regression plot as a png
plt.savefig("output_data/RegressionPlot_SouthernHemisphere_LatitudeVsCloudiness.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.057436539308802166

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There appears to be no significance in correlation between latitude and cloudiness.  In these analyses, the r-value is essentially zero.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
date = time.strftime("%m/%d/%y")
x_values = north_hemi["Lat"]
y_values = north_hemi["Wind Speed"]

# Get linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Build linear regression plot
plt.scatter(x_values, y_values, alpha = 0.7, edgecolors = "k")
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (5, 26), fontsize = 10, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Northern Hemisphere - City Latitude vs. Wind Speed ({date})", fontsize = 10)
plt.grid(True)
print(f"The r-value is: {rvalue**2}") 

# Save linear regression plot as a png
plt.savefig("output_data/RegressionPlot_NorthernHemisphere_LatitudeVsWindSpeed.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.05389137216819633

# %%
# Southern Hemisphere
date = time.strftime("%m/%d/%y")
x_values = south_hemi["Lat"]
y_values = south_hemi["Wind Speed"]

# Get linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Build linear regression plot
plt.scatter(x_values, y_values, alpha = 0.7, edgecolors = "k")
plt.plot(x_values, regress_values,"r")
plt.annotate(line_eq, (-18, 27), fontsize = 10, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"Southern Hemisphere - City Latitude vs. Wind Speed ({date})", fontsize = 10)
plt.grid(True)
print(f"The r-value is: {rvalue**2}") 

# Save linear regression plot as a png
plt.savefig("output_data/RegressionPlot_SouthernHemisphere_LatitudeVsWindSpeed.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.14264718418395267

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There appears to be no significance in correlation between latitude and wind speed.  In these analyses, the r-value is essentially zero.
